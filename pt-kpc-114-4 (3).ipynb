# %% [markdown]
# # 소개
#
# * 개발자
#
# * 4년
#
# * 빅데이터, 딥러닝

# %% [markdown]
# # 114회 컴퓨터시스템응용기술사  출제경향
#
# ### 1. CA/OS 다수 출제  CA 10문제, 네트워크 4문제, 보안 5문제
#
# * 총31문제 중 CA,NW,보안 19문제
# * CA 멜트다운관련 문제 - 멜트다운, TLB, 캐시메모리
# * 스케줄링 문제 - 선점형 스케줄링, RM 스케줄링
#
# ### 2. DS 8문제
# * 블록체인 연속 5회출제
#
# ### 3. 빈출
# * PMO, 감리,  CBD, RTOS스케줄링, 블록체인, 캐시메모리, 망중립성, SDN, NFV, 시큐어코딩, 5G, 기계학습 등등

# %%
import matplotlib.pyplot as plt
import matplotlib

# %matplotlib inline

# The slices will be ordered and plotted counter-clockwise.
labels = 'CA', 'NW', 'SEC', 'DS', 'IM', 'SE' , 'DB'
sizes = [10, 4, 5, 8, 1, 2, 0]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral', 'lime', 'pink', 'm']
explode = (0.1, 0.1, 0.1, 0.1 ,0,0,0) # only "explode" the 2nd slice (i.e. 'Hogs')

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)
# Set aspect ratio to be equal so that pie is drawn as a circle.
plt.axis('equal')

plt.show()

# %% [markdown]
# # 114회 컴퓨터시스템응용기술사  4교시 분석
#
# ## 1. 캐시메모리
#  * 매핑,교체정책
#  * 멜트다운
#
# ## 2. RM스케줄링
#  * 알고리즘 풀이
#
# ## 3. 블록체인
#  * 유형,적용분야, 문제점,해결방안
#  * 가상화폐 이슈
#
# ## 4. CBD방법론
#  * 고전
#
# ## 5. PMO/감리
#  * PMO활성화 문제
#
# ## 6. V2X
#  * 자율주행차 핵심기술

# %% [markdown]
# # 114회 컴퓨터시스템응용기술사  4교시 - 1번
#
# ### * 캐시(Cache) 메모리에서 주소 매핑(Mapping) 방식과 교체 알고리즘(Replacement algorithm)을 설명하시오.
#
# #### 1. 개요
#
# #### 2. 주소 매핑
#
# #### 3. 교체 알고리즘
#
# #### 4. 이슈,동향

# %% [markdown]
# ### 1단락 개요
#
# <img src="https://cdn.namuwikiusercontent.com/s/893cc4cb9901911dd7fbf7e151f8768f0a10d00d6b50bc9ad2b634810c19723f7c5464bc7701d8cfbfa7a4c3027ec10198c1cfcb92b598bd0eccea6202beb28af2f41dfc1122d25ce44ecde9d2d47b10?e=1526984424&k=m_V_GAwhDvLskx1eVvuSBA">
#
# ### *  지역성, 정책(인출 ,매핑, 교체, 쓰기)

# %% [markdown]
# ### 1단락 개요
#
#
# <img src="http://thumbnail.egloos.net/600x0/http://pds26.egloos.com/pds/201407/15/24/f0490324_53c53f5ee3c11.png">

# %% [markdown]
# 4.2. Cache Memory Principles}
# #1. word, block
# 	- [word] is the natural unit of organization of memory
# 	- 워드의 사이즈는 정수를 표현하는데 쓰이는 비트의 갯수와 같다
# 	- 워드의 사이즈는 instruction를 표현하는데 쓰이는 비트의 갯수와 같다
# 		ex. 32bit 컴퓨터에서 1word = 32bit = 4byte, 64bit 컴퓨터에서 1word = 64bit = 8byte
# 	- 워드의 사이즈가 n이면 메모리의 전체 addressable word는 2^n개이다
#
# 	- [block]은 K개의 word를 묶은 단위이다
# 	- 블락의 사이즈가 K이면 메모리의 전체 block의 갯수는 2^n/K이다. 이를 M이라고 두자
# 	- Cache에서는 block대신 line이라고 한다. "이때 line에는 tag bit와 control bit를 추가한다"(추후 설명)

# %% [markdown]
# ### 2단락 매핑방식
#
#
#
# ####  직접매핑
#
# <img src="http://thumbnail.egloos.net/600x0/http://pds21.egloos.com/pds/201407/16/24/f0490324_53c573307d78e.png">

# %% [markdown]
# ### 2단락 매핑방식
#
#
#
# #### 완전연관 매핑
#
# <img src="http://thumbnail.egloos.net/600x0/http://pds21.egloos.com/pds/201407/16/24/f0490324_53c57e28b2255.png">

# %% [markdown]
# ### 2단락 매핑방식
#
#
#
# ####  세트연관 매핑
#
# <img src="http://thumbnail.egloos.net/600x0/http://pds21.egloos.com/pds/201407/16/24/f0490324_53c599ae32885.png">

# %% [markdown]
# ### 3단락 교체알고리즘
#
#
# ##### * LRU - Least Recently Used
#
# ##### * FIFO - First In First Out
#
# ##### * LFU - Least Frequently Used
#
# ##### * Random

# %% [markdown]
# <img src="https://github.com/sanghyunpark/ml_src/blob/master/m1.JPG?raw=true">

# %% [markdown]
# # 114회 컴퓨터시스템응용기술사  4교시 - 2번
#
# ### * RM(Rate Monotonic) 스케줄링 알고리즘을 설명하고, 다음 3개의 태스크(Task)를 스케줄링 하시오.
#
# #### 1. RTOS스케줄링 개요
#
# #### 2. RM스케줄링 정의, 특징, 동작방식
#
# #### 3. 문제에서 제시한 태스크의 RM스케줄링

# %% [markdown]
# ### 1. RTOS스케줄링 개요
#
# ##### * 실시간 시스템 - 제한된 응답시간이나 오동작을 포함한 결과의 위험성에 관한 명확한 규정을 만족하는 시스템
#
# - 경성 실시간 시스템(Hard Real-time)
# - 준경성 실시간 시스템(Firm Real-time)
# - 연성 실시간 시스템(Soft Real-time)
#
#
# ##### * 실시간 스케줄링 - 실시간 운영체제의 스케줄러는 선점을 이용한 우선순위 기반의 스케줄링 알고리즘을 지원해야함
#
# ##### * 비율 단조 스케줄링 (rate-monotonic scheduling) - 수행 주기가 가장 짧은 프로세스에 가장 높은 우선순위를 부여하는 방식의 알고리즘
#
# ##### *  최단 마감 우선 스케줄링 (Earliest Deadline First Scheduling) - 현재 준비상태에 있는 태스크들 중에서 마감시간이 가장 짧은 태스크를 선택하여 수행

# %% [markdown]
# ### 2. RM스케줄링 정의, 특징, 동작방식
#
# #### 특징 - 선점형, 프로세스 수행시간 일정, 마감시각은 마지막 주기가 끝나는 시점
#
#
# #### 충분조건
# - CPU이용율(U) ≤N(2^(1/N)-1)
# - 태스크의 개수 N이 증가함에 따라 이용율은 점점 감소하여 69.3%에 수렴함
# - 2개 태스크일 경우는 약 83%
# - 무한개 태스크일 경우는 약 69%임
#
# #### 동작방식
# 1. 각 주기 Task들에 대해 우선순위 지정
# 2. 주기에 반비례하여 우선순위 배정함(주기가 짧으면 높은 우선순위, 길면 낮은 우선순위)
# 3. 선점가능한 정적 우선순위 정책을 사용하여 주기적인 Task 스케줄링 수행

# %% [markdown]
# ### 3. 문제에서 제시한 태스크의 RM스케줄링
#
# <img src="https://github.com/sanghyunpark/ml_src/blob/master/m2.JPG?raw=true">
#
# <img src="https://github.com/sanghyunpark/ml_src/blob/master/m3.JPG?raw=true">

# %% [markdown]
# # 114회 컴퓨터시스템응용기술사  4교시 - 3번
#
# ### * 미래 핵심기술로 주목받고 있는 블록체인(Block Chain)의 유형과 산업별 적용분야 및 문제점, 해결방안에 대하여 설명하시오
#
# #### 1. 미래 핵심기술로 주목 받고 있는 블록체인(Block Chain)의 개요
#
# #### 2. 블록체인의 유형
#
# #### 3.	블록체인의 산업별 적용분야
#
# #### 4.	블록체인의 문제점, 해결방안

# %% [markdown]
# ### 1. 미래 핵심기술로 주목 받고 있는 블록체인(Block Chain)의 개요
#
# ##### * 거래정보를 기록한 원장을 특정 기관의 중앙 서버가 아닌 P2P 네트워크에 분산하여 참가자가 공동으로 기록하고 관리하는 기술
#
# ##### * 보안성 및 안전성
#
# ##### * 무결성 및 신뢰성
#
# ##### *  효율성 및 신속성

# %% [markdown]
# ### 2. 블록체인의 유형
#
# <img src="https://github.com/sanghyunpark/ml_src/blob/master/m4.JPG?raw=true">

# %% [markdown]
# ### 3.	블록체인의 산업별 적용분야
#
#
# <img src="https://github.com/sanghyunpark/ml_src/blob/master/m5.jpg?raw=true">
#
#
# <img src="https://github.com/sanghyunpark/ml_src/blob/master/m6.JPG?raw=true">

# %% [markdown]
# ### 4.	블록체인의 문제점, 해결방안
#
#
# <img src="https://github.com/sanghyunpark/ml_src/blob/master/m7.JPG?raw=true">

# %% [markdown]
# ### 5.	블록체인기술의 가상화폐 시장의 동향 및 시사점
#
#
# <img src="https://github.com/sanghyunpark/ml_src/blob/master/m8.JPG?raw=true">

# %% [markdown]
# # 114회 컴퓨터시스템응용기술사  4교시 - 4번
#
# ### * 정보공학방법론으로 개발되어 운영 중인 시스템을 CBD(Component Based Development) 방법론으로 적용하여 개발하고자 한다. CBD 방법론의 요소기술 및 개발공정, 개발과정에서 발생될 수 있는 문제점과 해결방안에 대하여 설명하시오.
#
# #### 1.	컴포넌트 재사용을 통한 생산성과 품질향상, CBD방법론의 개요
#
# #### 2.	CBD방법론의 요소기술과 개발공정
#
# #### 3.	CBD방법론의 개발과정에서 발생될 수 있는 문제점 및 해결방안

# %% [markdown]
# ### 1.	컴포넌트 재사용을 통한 생산성과 품질향상, CBD방법론의 개요
#
# <img src="https://github.com/sanghyunpark/ml_src/blob/master/m11.JPG?raw=true">

# %% [markdown]
# ### 2.	CBD방법론의 요소기술과 개발공정
#
# <img src="https://github.com/sanghyunpark/ml_src/blob/master/m12.JPG?raw=true">
# <img src="https://github.com/sanghyunpark/ml_src/blob/master/m13.JPG?raw=true">

# %% [markdown]
# <img src="https://github.com/sanghyunpark/ml_src/blob/master/m14.JPG?raw=true">
# <img src="https://github.com/sanghyunpark/ml_src/blob/master/m15.JPG?raw=true">

# %% [markdown]
# ### 3.	CBD방법론의 개발과정에서 발생될 수 있는 문제점 및 해결방안
#
# <img src="https://github.com/sanghyunpark/ml_src/blob/master/m16.JPG?raw=true">

# %% [markdown]
# # 114회 컴퓨터시스템응용기술사  4교시 - 5번
#
# ### * 대규모로 운영 중인 시스템을 개편하기 위해 PMO와 감리가 참여하는 프로젝트를 추진하고자 한다 개발단계에서의 PMO와 감리간의 역할, PMO 한계점 및 해결방안에 대하여 설명하시오.
#
# #### 1.	PMO와 감리의 개요
#
# #### 2. 개발단계에서의 PMO와 감리간의 역할
#
# #### 3. PMO의 한계점과 해결방안
#
# #### 4. 분할발주시 PMO의 효율적인 활용방안

# %% [markdown]
# ### 1.	PMO와 감리의 개요
#
# <img src="https://github.com/sanghyunpark/ml_src/blob/master/m41.JPG?raw=true">

# %% [markdown]
# ### 2. 개발단계에서의 PMO와 감리간의 역할
#
# <img src="https://github.com/sanghyunpark/ml_src/blob/master/m421.JPG?raw=true">
# <img src="https://github.com/sanghyunpark/ml_src/blob/master/m422.JPG?raw=true">
# <img src="https://github.com/sanghyunpark/ml_src/blob/master/m423.JPG?raw=true">

# %% [markdown]
# ### 3. PMO의 한계점과 해결방안
#
# <img src="https://github.com/sanghyunpark/ml_src/blob/master/m431.JPG?raw=true">
# <img src="https://github.com/sanghyunpark/ml_src/blob/master/m432.JPG?raw=true">
# <img src="https://github.com/sanghyunpark/ml_src/blob/master/m433.JPG?raw=true">

# %% [markdown]
# ### 4. 분할발주시 PMO의 효율적인 활용방안
#
# <img src="https://github.com/sanghyunpark/ml_src/blob/master/m44.JPG?raw=true">

# %% [markdown]
# # 114회 컴퓨터시스템응용기술사  4교시 - 6번
#
# ### * 유무선 통신망을 활용한 차량 통신기술인 V2X(Vehicle to Everything)의 종류와 통신 표준에 대하여 설명하시오.
#
# #### 1. 유무선 통신망을 활용한 차량 통신기술인 V2X(Vehicle to Everything)의 개요
#
# #### 2. V2X(Vehicle to Everything)의 종류
#
# #### 3. V2X(Vehicle to Everything)의 통신표준
#
# #### 4.국내 V2X(Vehicle to Everything)의 발전을 위한 현황 및 제언

# %% [markdown]
# ### 1. 유무선 통신망을 활용한 차량 통신기술인 V2X(Vehicle to Everything)의 개요
#
# <img src="https://github.com/sanghyunpark/ml_src/blob/master/m61.JPG?raw=true">

# %% [markdown]
# ### 2. V2X(Vehicle to Everything)의 종류
#
# <img src="https://github.com/sanghyunpark/ml_src/blob/master/m621.JPG?raw=true">
# <img src="https://github.com/sanghyunpark/ml_src/blob/master/m622.JPG?raw=true">

# %% [markdown]
# ### 3. V2X(Vehicle to Everything)의 통신표준
#
#
# <img src="https://github.com/sanghyunpark/ml_src/blob/master/m631.JPG?raw=true">
# <img src="https://github.com/sanghyunpark/ml_src/blob/master/m632.JPG?raw=true">

# %% [markdown]
# ### 4. 국내 V2X(Vehicle to Everything)의 발전을 위한 현황 및 제언
#
# <img src="https://github.com/sanghyunpark/ml_src/blob/master/m64.JPG?raw=true">

# %% [markdown]
# # 기술사 합격 노하우
#
# <img src="https://github.com/sanghyunpark/ml_src/blob/master/m9.JPG?raw=true">

# %% [markdown]
# <img src="https://github.com/sanghyunpark/ml_src/blob/master/m10.JPG?raw=true">

# %% [markdown]
# # 질의응답
